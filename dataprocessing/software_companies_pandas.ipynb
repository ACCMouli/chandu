# %% [markdown]
# ## 1. Load the dataset and display the first 5 rows.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/giridhar276/genai/refs/heads/main/dataprocessing/software_companies_dataset.csv')
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0    1.121530e+08         11.15      Hardware   16874822.81             51.54
# 1    1.484237e+08         47.93      Hardware   32905733.95             57.78
# 2    7.609940e+08         46.69    Networking   45386922.83             73.96
# 3    7.958320e+08         47.05      Services   37711635.48             13.65
# 4    7.063862e+08         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5

# %% [markdown]
# ## 2. Display the summary statistics of the dataset.

# %%
df.describe()
# Out:
#           Company_ID  Year_Founded   Employees  Annual_Revenue  Market_Share  \
# count    1000.000000   1000.000000  1000.00000    1.000000e+03   1000.000000
# mean   545713.387000   1999.313000  2451.20000    4.996386e+08     25.250070
# std    258624.607673     11.466844  1386.23205    2.858670e+08     14.663117
# min    100317.000000   1980.000000    53.00000    2.134045e+06      0.010000
# 25%    323647.750000   1989.000000  1322.25000    2.621710e+08     12.467500
# 50%    547569.000000   1999.000000  2393.50000    4.930957e+08     25.100000
# 75%    765875.250000   2009.000000  3582.25000    7.428693e+08     37.827500
# max    999534.000000   2019.000000  4998.00000    9.998246e+08     49.980000
#
#        R&D_Spending  Adoption_Rate_AI  Adoption_Rate_Cloud  \
# count  1.000000e+03       1000.000000          1000.000000
# mean   2.500037e+07         50.558820            51.553950
# std    1.403837e+07         27.771751            28.259477
# min    5.356223e+05          0.000000             0.030000
# 25%    1.364892e+07         27.315000            27.860000
# 50%    2.497328e+07         51.160000            52.025000
# 75%    3.688927e+07         74.165000            75.920000
# max    4.998062e+07         99.910000            99.970000
#
#        Adoption_Rate_Blockchain  CEO_Tenure_Years
# count               1000.000000       1000.000000
# mean                  49.559770         14.734000
# std                   29.469011          8.311819
# min                    0.040000          1.000000
# 25%                   22.735000          8.000000
# 50%                   50.210000         14.500000
# 75%                   75.122500         22.000000
# max                   99.980000         29.000000

# %% [markdown]
# ## 3. Check for missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# Company_ID                  0
# Company_Name                0
# Year_Founded                0
# Employees                   0
# Annual_Revenue              0
# Market_Share                0
# Product_Lines               0
# R&D_Spending                0
# Adoption_Rate_AI            0
# Adoption_Rate_Cloud         0
# Adoption_Rate_Blockchain    0
# CEO_Tenure_Years            0
# dtype: int64

# %% [markdown]
# ## 4. Drop rows with any missing values.

# %%
df.dropna(inplace=True)
df.head()

# or
#df=df.dropna()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0    1.121530e+08         11.15      Hardware   16874822.81             51.54
# 1    1.484237e+08         47.93      Hardware   32905733.95             57.78
# 2    7.609940e+08         46.69    Networking   45386922.83             73.96
# 3    7.958320e+08         47.05      Services   37711635.48             13.65
# 4    7.063862e+08         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5

# %% [markdown]
# ## 5. Fill missing values with the mean for numerical columns.

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0    1.121530e+08         11.15      Hardware   16874822.81             51.54
# 1    1.484237e+08         47.93      Hardware   32905733.95             57.78
# 2    7.609940e+08         46.69    Networking   45386922.83             73.96
# 3    7.958320e+08         47.05      Services   37711635.48             13.65
# 4    7.063862e+08         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5

# %% [markdown]
# ## 6. Fill missing values with the mode for categorical columns.

# %%
df.fillna(df.mode(numeric_only=True), inplace=True)
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0    1.121530e+08         11.15      Hardware   16874822.81             51.54
# 1    1.484237e+08         47.93      Hardware   32905733.95             57.78
# 2    7.609940e+08         46.69    Networking   45386922.83             73.96
# 3    7.958320e+08         47.05      Services   37711635.48             13.65
# 4    7.063862e+08         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5

# %% [markdown]
# ## 7. Create a new column 'Company_Age' based on 'Year_Founded' and the current year.

# %%
df['Company_Age'] = 2024 - df['Year_Founded']
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0    1.121530e+08         11.15      Hardware   16874822.81             51.54
# 1    1.484237e+08         47.93      Hardware   32905733.95             57.78
# 2    7.609940e+08         46.69    Networking   45386922.83             73.96
# 3    7.958320e+08         47.05      Services   37711635.48             13.65
# 4    7.063862e+08         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age
# 0           22
# 1           23
# 2           16
# 3           39
# 4           13

# %% [markdown]
# ## 8. Calculate the correlation matrix for numerical columns.

# %%
df.corr( numeric_only=True)
# Out:
#                           Company_ID  Year_Founded  Employees  Annual_Revenue  \
# Company_ID                  1.000000     -0.001154   0.033418        0.001962
# Year_Founded               -0.001154      1.000000  -0.035116        0.000812
# Employees                   0.033418     -0.035116   1.000000        0.051415
# Annual_Revenue              0.001962      0.000812   0.051415        1.000000
# Market_Share               -0.004818      0.073646   0.031781        0.007155
# R&D_Spending                0.011137     -0.119146   0.012425       -0.050425
# Adoption_Rate_AI            0.015739      0.042016  -0.045807       -0.069875
# Adoption_Rate_Cloud         0.021063      0.024702  -0.006495       -0.013711
# Adoption_Rate_Blockchain    0.012187     -0.051170  -0.019140        0.014555
# CEO_Tenure_Years           -0.007343     -0.053917  -0.064405       -0.008989
# Company_Age                 0.001154     -1.000000   0.035116       -0.000812
#
#                           Market_Share  R&D_Spending  Adoption_Rate_AI  \
# Company_ID                   -0.004818      0.011137          0.015739
# Year_Founded                  0.073646     -0.119146          0.042016
# Employees                     0.031781      0.012425         -0.045807
# Annual_Revenue                0.007155     -0.050425         -0.069875
# Market_Share                  1.000000      0.053084         -0.023632
# R&D_Spending                  0.053084      1.000000         -0.038283
# Adoption_Rate_AI             -0.023632     -0.038283          1.000000
# Adoption_Rate_Cloud          -0.011048     -0.011859          0.013096
# Adoption_Rate_Blockchain     -0.031381     -0.021093          0.024468
# CEO_Tenure_Years              0.060530     -0.029504         -0.035414
# Company_Age                  -0.073646      0.119146         -0.042016
#
#                           Adoption_Rate_Cloud  Adoption_Rate_Blockchain  \
# Company_ID                           0.021063                  0.012187
# Year_Founded                         0.024702                 -0.051170
# Employees                           -0.006495                 -0.019140
# Annual_Revenue                      -0.013711                  0.014555
# Market_Share                        -0.011048                 -0.031381
# R&D_Spending                        -0.011859                 -0.021093
# Adoption_Rate_AI                     0.013096                  0.024468
# Adoption_Rate_Cloud                  1.000000                  0.043864
# Adoption_Rate_Blockchain             0.043864                  1.000000
# CEO_Tenure_Years                     0.014219                 -0.027825
# Company_Age                         -0.024702                  0.051170
#
#                           CEO_Tenure_Years  Company_Age
# Company_ID                       -0.007343     0.001154
# Year_Founded                     -0.053917    -1.000000
# Employees                        -0.064405     0.035116
# Annual_Revenue                   -0.008989    -0.000812
# Market_Share                      0.060530    -0.073646
# R&D_Spending                     -0.029504     0.119146
# Adoption_Rate_AI                 -0.035414    -0.042016
# Adoption_Rate_Cloud               0.014219    -0.024702
# Adoption_Rate_Blockchain         -0.027825     0.051170
# CEO_Tenure_Years                  1.000000     0.053917
# Company_Age                       0.053917     1.000000

# %% [markdown]
# ## 9. Plot a histogram for the 'Annual_Revenue' column.

# %%
df['Annual_Revenue'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ## 10. Plot a bar chart for the 'Product_Lines' column.

# %%
df['Product_Lines'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Lines'>

# %% [markdown]
# ## 11. Plot a scatter plot between 'R&D_Spending' and 'Annual_Revenue'.

# %%
df.plot.scatter(x='R&D_Spending', y='Annual_Revenue')
#df.plot.
# Out:
# <Axes: xlabel='R&D_Spending', ylabel='Annual_Revenue'>

# %% [markdown]
# ## 13. Normalize the 'Annual_Revenue' column using Min-Max scaling.

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.preprocessing import MinMaxScaler     # scaling columns(scaling techniques) with big values to bring them to a comparable scale for better accuracy in the model
scaler = MinMaxScaler()
df['Annual_Revenue'] = scaler.fit_transform(df[['Annual_Revenue']])
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0        0.110274         11.15      Hardware   16874822.81             51.54
# 1        0.146628         47.93      Hardware   32905733.95             57.78
# 2        0.760617         46.69    Networking   45386922.83             73.96
# 3        0.795535         47.05      Services   37711635.48             13.65
# 4        0.705882         23.07      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age
# 0           22
# 1           23
# 2           16
# 3           39
# 4           13

# %% [markdown]
# ## 14. Standardize the 'Market_Share' column.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Market_Share'] = scaler.fit_transform(df[['Market_Share']])
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0        0.110274     -0.962082      Hardware   16874822.81             51.54
# 1        0.146628      1.547507      Hardware   32905733.95             57.78
# 2        0.760617      1.462899    Networking   45386922.83             73.96
# 3        0.795535      1.487463      Services   37711635.48             13.65
# 4        0.705882     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age
# 0           22
# 1           23
# 2           16
# 3           39
# 4           13

# %% [markdown]
# ## 15. Create a pivot table showing the average 'R&D_Spending' for each 'Product_Lines'.

# %%
df.pivot_table(values='R&D_Spending', index='Product_Lines', aggfunc='mean')
# Out:
#                R&D_Spending
# Product_Lines
# Consulting     2.514793e+07
# Hardware       2.490118e+07
# Networking     2.516956e+07
# Services       2.585539e+07
# Software       2.395849e+07

# %% [markdown]
# ## 16. Group the data by 'CEO_Tenure_Years' and calculate the mean 'Annual_Revenue'.

# %%
df.groupby('CEO_Tenure_Years')['Annual_Revenue'].mean()
# Out:
# CEO_Tenure_Years
# 1     0.493896
# 2     0.500679
# 3     0.506677
# 4     0.505318
# 5     0.483152
# 6     0.462120
# 7     0.479923
# 8     0.561232
# 9     0.527199
# 10    0.490550
# 11    0.568818
# 12    0.508565
# 13    0.494017
# 14    0.514049
# 15    0.469953
# 16    0.512843
# 17    0.470323
# 18    0.474575
# 19    0.473077
# 20    0.484048
# 21    0.475983
# 22    0.509962
# 23    0.445867
# 24    0.507446
# 25    0.508246
# 26    0.503584
# 27    0.533427
# 28    0.484021
# 29    0.504979
# Name: Annual_Revenue, dtype: float64

# %% [markdown]
# ## 17. Filter the dataset for companies with 'Annual_Revenue' greater than 50 million.

# %%
df_filtered = df[df['Annual_Revenue'] > 5e7]
df_filtered.head()
# Out:
# Empty DataFrame
# Columns: [Company_ID, Company_Name, Year_Founded, Employees, Annual_Revenue, Market_Share, Product_Lines, R&D_Spending, Adoption_Rate_AI, Adoption_Rate_Cloud, Adoption_Rate_Blockchain, CEO_Tenure_Years, Company_Age]
# Index: []

# %%
df_filtered = df[df['Annual_Revenue'] > 0.2]
df_filtered.head()
# Out:
#    Company_ID              Company_Name  Year_Founded  Employees  \
# 2      161950   Barker, Sims and Walker          2008        158
# 3      426522              Castro-Simon          1985       2826
# 4      688832   Hughes, Mills and Stout          2011       3238
# 7      263362  Simon, Martin and Barber          1997       2444
# 8      851708            Montgomery Ltd          2008       1779
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 2        0.760617      1.462899    Networking   45386922.83             73.96
# 3        0.795535      1.487463      Services   37711635.48             13.65
# 4        0.705882     -0.148752      Software   10117516.57             84.11
# 7        0.382824      1.247967    Consulting   32258576.91             98.47
# 8        0.619458     -0.686423    Networking   15793134.96             99.53
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
# 7                15.47                     24.56                24
# 8                31.86                     89.24                 5
#
#    Company_Age
# 2           16
# 3           39
# 4           13
# 7           27
# 8           16

# %% [markdown]
# ## 18. Sort the dataset by 'Market_Share' in descending order.

# %%
df.sort_values(by='Market_Share', ascending=False).head()
# Out:
#      Company_ID      Company_Name  Year_Founded  Employees  Annual_Revenue  \
# 287      118389  Johnson and Sons          2019       1712        0.323352
# 411      476760      Miles-Miller          2019        720        0.123343
# 838      999534           Liu Inc          2003       1176        0.993209
# 535      531862           Roy Ltd          1984       4371        0.262712
# 882      248629  Ramirez-Campbell          1989        260        0.495968
#
#      Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 287      1.687384      Hardware   22638212.89             65.44
# 411      1.677831    Networking    6576380.98             86.81
# 838      1.674420    Consulting   35889739.95             54.22
# 535      1.673055    Consulting   42344659.49             35.67
# 882      1.667596      Services   34862271.82             68.93
#
#      Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 287                64.04                     82.40                25
# 411                59.22                     35.73                15
# 838                47.39                     56.03                16
# 535                61.34                     71.01                26
# 882                10.70                     93.32                26
#
#      Company_Age
# 287            5
# 411            5
# 838           21
# 535           40
# 882           35

# %% [markdown]
# ## 19. Create a new column 'Revenue_per_Employee' by dividing 'Annual_Revenue' by 'Employees'.

# %%
df['Revenue_per_Employee'] = df['Annual_Revenue'] / df['Employees']
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0        0.110274     -0.962082      Hardware   16874822.81             51.54
# 1        0.146628      1.547507      Hardware   32905733.95             57.78
# 2        0.760617      1.462899    Networking   45386922.83             73.96
# 3        0.795535      1.487463      Services   37711635.48             13.65
# 4        0.705882     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age  Revenue_per_Employee
# 0           22              0.000051
# 1           23              0.000122
# 2           16              0.004814
# 3           39              0.000282
# 4           13              0.000218

# %% [markdown]
# ## 20. Replace all instances of 'Networking' in the 'Product_Lines' column with 'IT Services'.

# %%
df['Product_Lines'].replace('Networking', 'IT Services', inplace=True)
df.head()
# Out:
# /tmp/ipython-input-3596144190.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Lines'].replace('Networking', 'IT Services', inplace=True)
#    Company_ID             Company_Name  Year_Founded  Employees  \
# 0      115525                 Mora-Kim          2002       2168
# 1      779751           Myers and Sons          2001       1199
# 2      161950  Barker, Sims and Walker          2008        158
# 3      426522             Castro-Simon          1985       2826
# 4      688832  Hughes, Mills and Stout          2011       3238
#
#    Annual_Revenue  Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0        0.110274     -0.962082      Hardware   16874822.81             51.54
# 1        0.146628      1.547507      Hardware   32905733.95             57.78
# 2        0.760617      1.462899   IT Services   45386922.83             73.96
# 3        0.795535      1.487463      Services   37711635.48             13.65
# 4        0.705882     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age  Revenue_per_Employee
# 0           22              0.000051
# 1           23              0.000122
# 2           16              0.004814
# 3           39              0.000282
# 4           13              0.000218

# %% [markdown]
# ## 21. Rename the column 'Annual_Revenue' to 'Revenue'.

# %%
df.rename(columns={'Annual_Revenue': 'Revenue'}, inplace=True)
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  CEO_Tenure_Years  \
# 0                63.10                     39.65                11
# 1                28.83                     95.42                 7
# 2                22.23                     12.42                19
# 3                21.07                     22.27                 4
# 4                71.37                     41.71                 5
#
#    Company_Age  Revenue_per_Employee
# 0           22              0.000051
# 1           23              0.000122
# 2           16              0.004814
# 3           39              0.000282
# 4           13              0.000218

# %% [markdown]
# ## 22. Drop the 'CEO_Tenure_Years' column from the dataset.

# %%
df.drop(columns=['CEO_Tenure_Years'], inplace=True)
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee
# 0              0.000051
# 1              0.000122
# 2              0.004814
# 3              0.000282
# 4              0.000218

# %% [markdown]
# ## 23. Check for duplicate rows in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 24. Drop any duplicate rows found.

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee
# 0              0.000051
# 1              0.000122
# 2              0.004814
# 3              0.000282
# 4              0.000218

# %% [markdown]
# ## 25. Create a new DataFrame containing only 'Company_ID', 'Company_Name', and 'Revenue'.

# %%
df_subset = df[['Company_ID', 'Company_Name', 'Revenue']]
df_subset.head()
# Out:
#    Company_ID             Company_Name   Revenue
# 0      115525                 Mora-Kim  0.110274
# 1      779751           Myers and Sons  0.146628
# 2      161950  Barker, Sims and Walker  0.760617
# 3      426522             Castro-Simon  0.795535
# 4      688832  Hughes, Mills and Stout  0.705882

# %% [markdown]
# ## 26. Merge the new DataFrame with the original dataset on 'Company_ID'.

# %%
df_merged = pd.merge(df_subset, df, on='Company_ID')
df_merged.head()
# Out:
#    Company_ID           Company_Name_x  Revenue_x           Company_Name_y  \
# 0      115525                 Mora-Kim   0.110274                 Mora-Kim
# 1      779751           Myers and Sons   0.146628           Myers and Sons
# 2      161950  Barker, Sims and Walker   0.760617  Barker, Sims and Walker
# 3      426522             Castro-Simon   0.795535             Castro-Simon
# 4      688832  Hughes, Mills and Stout   0.705882  Hughes, Mills and Stout
#
#    Year_Founded  Employees  Revenue_y  Market_Share Product_Lines  \
# 0          2002       2168   0.110274     -0.962082      Hardware
# 1          2001       1199   0.146628      1.547507      Hardware
# 2          2008        158   0.760617      1.462899   IT Services
# 3          1985       2826   0.795535      1.487463      Services
# 4          2011       3238   0.705882     -0.148752      Software
#
#    R&D_Spending  Adoption_Rate_AI  Adoption_Rate_Cloud  \
# 0   16874822.81             51.54                63.10
# 1   32905733.95             57.78                28.83
# 2   45386922.83             73.96                22.23
# 3   37711635.48             13.65                21.07
# 4   10117516.57             84.11                71.37
#
#    Adoption_Rate_Blockchain  Company_Age  Revenue_per_Employee
# 0                     39.65           22              0.000051
# 1                     95.42           23              0.000122
# 2                     12.42           16              0.004814
# 3                     22.27           39              0.000282
# 4                     41.71           13              0.000218

# %% [markdown]
# ## 27. Create a cross-tabulation of 'Product_Lines' and 'Market_Share'.

# %%
pd.crosstab(df['Product_Lines'], df['Market_Share'])
# Out:
# Market_Share   -1.722192  -1.713322  -1.710592  -1.709910  -1.705816  \
# Product_Lines
# Consulting             0          0          1          0          0
# Hardware               0          0          0          0          1
# IT Services            0          0          0          1          0
# Services               1          0          0          0          0
# Software               0          1          0          0          0
#
# Market_Share   -1.705134  -1.701722  -1.698310  -1.697628  -1.696263  ...  \
# Product_Lines                                                         ...
# Consulting             0          0          1          0          0  ...
# Hardware               0          0          0          1          1  ...
# IT Services            0          1          0          0          0  ...
# Services               0          0          0          0          0  ...
# Software               1          0          0          0          0  ...
#
# Market_Share    1.654632   1.655314   1.657361   1.660773   1.661455  \
# Product_Lines
# Consulting             0          1          1          0          0
# Hardware               0          0          0          0          0
# IT Services            0          0          0          1          1
# Services               0          0          0          0          0
# Software               1          0          0          0          0
#
# Market_Share    1.667596   1.673055   1.674420   1.677831   1.687384
# Product_Lines
# Consulting             0          1          1          0          0
# Hardware               0          0          0          0          1
# IT Services            0          0          0          1          0
# Services               1          0          0          0          0
# Software               0          0          0          0          0
#
# [5 rows x 932 columns]

# %% [markdown]
# ## 28. Create a pivot table showing the count of companies by 'Product_Lines' and 'Year_Founded'.

# %%
df.pivot_table(index='Product_Lines', columns='Year_Founded', aggfunc='size', fill_value=0)
# Out:
# Year_Founded   1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  \
# Product_Lines
# Consulting        2     3    10     4    10     3     3     2     0     6
# Hardware          8     2     8     7     2     5     6     5     4    10
# IT Services       4     2     5     7     2     5     5     6     7     7
# Services          8     6     5     7     6     4     8     4     4     5
# Software          9     5     4     6     6     4     4     2     5     6
#
# Year_Founded   ...  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# Product_Lines  ...
# Consulting     ...     6     9     4     7     4     3     2     5     2     3
# Hardware       ...     5     6     2     5     3     2     7     5     5    10
# IT Services    ...     8     5     1     3     6     8     5     3     5     6
# Services       ...     6     8     4     6     6     2     6     5     8     3
# Software       ...     6     9     4     5     4     3     3     6     4     2
#
# [5 rows x 40 columns]

# %% [markdown]
# ## 29. Replace missing values in 'Market_Share' with the median.

# %%
df['Market_Share'].fillna(df['Market_Share'].median(), inplace=True)
df.head()
# Out:
# /tmp/ipython-input-1112479773.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Market_Share'].fillna(df['Market_Share'].median(), inplace=True)
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee
# 0              0.000051
# 1              0.000122
# 2              0.004814
# 3              0.000282
# 4              0.000218

# %% [markdown]
# ## 30. Calculate the Z-score for the 'Annual_Revenue' column.

# %%
from scipy.stats import zscore
df['Annual_Revenue_Zscore'] = zscore(df['Revenue'])
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore
# 0              0.000051              -1.356153
# 1              0.000122              -1.229210
# 2              0.004814               0.914712
# 3              0.000282               1.036641
# 4              0.000218               0.723592

# %% [markdown]
# ## 31. Filter out outliers in the 'Annual_Revenue' column based on Z-score.

# %%
df_no_outliers = df[(df['Annual_Revenue_Zscore'] > -3) & (df['Annual_Revenue_Zscore'] < 3)]
df_no_outliers.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore
# 0              0.000051              -1.356153
# 1              0.000122              -1.229210
# 2              0.004814               0.914712
# 3              0.000282               1.036641
# 4              0.000218               0.723592

# %% [markdown]
# ## 32. Apply a lambda function to the 'Market_Share' column to categorize into 'Low', 'Medium', 'High'.

# %%
df['Market_Share_Category'] = df['Market_Share'].apply(lambda x: 'Low' if x < 10 else 'Medium' if x < 30 else 'High')
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low

# %% [markdown]
# ## 33. Create a new column 'Total_Tech_Adoption' by summing 'Adoption_Rate_AI', 'Adoption_Rate_Cloud', and 'Adoption_Rate_Blockchain'.

# %%
df['Total_Tech_Adoption'] = df['Adoption_Rate_AI'] + df['Adoption_Rate_Cloud'] + df['Adoption_Rate_Blockchain']
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption
# 0               154.29
# 1               182.03
# 2               108.61
# 3                56.99
# 4               197.19

# %% [markdown]
# ## 34. Extract the decade from 'Year_Founded' and create a new column 'Founded_Decade'.

# %%
df['Founded_Decade'] = (df['Year_Founded'] // 10) * 10
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade
# 0               154.29            2000
# 1               182.03            2000
# 2               108.61            2000
# 3                56.99            1980
# 4               197.19            2010

# %% [markdown]
# ## 35. Convert the 'Product_Lines' column to a categorical data type.

# %%
df['Product_Lines'] = df['Product_Lines'].astype('category')
df.dtypes
# Out:
# Company_ID                     int64
# Company_Name                  object
# Year_Founded                   int64
# Employees                      int64
# Revenue                      float64
# Market_Share                 float64
# Product_Lines               category
# R&D_Spending                 float64
# Adoption_Rate_AI             float64
# Adoption_Rate_Cloud          float64
# Adoption_Rate_Blockchain     float64
# Company_Age                    int64
# Revenue_per_Employee         float64
# Annual_Revenue_Zscore        float64
# Market_Share_Category         object
# Total_Tech_Adoption          float64
# Founded_Decade                 int64
# dtype: object

# %% [markdown]
# ## 36. Create a box plot for 'Annual_Revenue' across different 'Product_Lines'.

# %%
df.boxplot(column='Revenue', by='Product_Lines')
# Out:
# <Axes: title={'center': 'Revenue'}, xlabel='Product_Lines'>

# %% [markdown]
# ## 37. Create a line plot showing the trend of 'Annual_Revenue' over 'Company_Age'.

# %%
df.groupby('Company_Age')['Revenue'].mean().plot()
# Out:
# <Axes: xlabel='Company_Age'>

# %% [markdown]
# ## 38. Create a heatmap for the correlation matrix.

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 39. Filter the dataset to include only companies with 'Product_Lines' as 'Software'.

# %%
df_software = df[df['Product_Lines'] == 'Software']
df_software.head()
# Out:
#     Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 4       688832  Hughes, Mills and Stout          2011       3238  0.705882
# 5       658452                  Lee Ltd          2005       2786  0.042900
# 6       398886            Martin-Barton          1986       4776  0.133294
# 9       977735   Bass, Bell and Camacho          2001       3006  0.239415
# 15      336464               Lowery LLC          1986       1215  1.000000
#
#     Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 4      -0.148752      Software   10117516.57             84.11
# 5       0.782621      Software    1308217.06             16.75
# 6       0.871324      Software   11535421.15             52.72
# 9      -0.926601      Software   10385978.42              4.95
# 15     -1.419240      Software    3312071.93             80.51
#
#     Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 4                 71.37                     41.71           13
# 5                  4.20                     73.39           19
# 6                 23.10                     16.23           38
# 9                 32.48                     58.77           23
# 15                78.00                     60.29           38
#
#     Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 4               0.000218               0.723592                   Low
# 5               0.000015              -1.591408                   Low
# 6               0.000028              -1.275771                   Low
# 9               0.000080              -0.905219                   Low
# 15              0.000823               1.750591                   Low
#
#     Total_Tech_Adoption  Founded_Decade
# 4                197.19            2010
# 5                 94.34            2000
# 6                 92.05            1980
# 9                 96.20            2000
# 15               218.80            1980

# %% [markdown]
# ## 40. Replace outliers in 'R&D_Spending' with the median value.

# %%
median_value = df['R&D_Spending'].median()
df.loc[df['R&D_Spending'] > df['R&D_Spending'].quantile(0.99), 'R&D_Spending'] = median_value
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade
# 0               154.29            2000
# 1               182.03            2000
# 2               108.61            2000
# 3                56.99            1980
# 4               197.19            2010

# %% [markdown]
# ## 41. Calculate the percentage of missing values in each column.

# %%
missing_percent = df.isnull().mean() * 100
missing_percent
# Out:
# Company_ID                  0.0
# Company_Name                0.0
# Year_Founded                0.0
# Employees                   0.0
# Revenue                     0.0
# Market_Share                0.0
# Product_Lines               0.0
# R&D_Spending                0.0
# Adoption_Rate_AI            0.0
# Adoption_Rate_Cloud         0.0
# Adoption_Rate_Blockchain    0.0
# Company_Age                 0.0
# Revenue_per_Employee        0.0
# Annual_Revenue_Zscore       0.0
# Market_Share_Category       0.0
# Total_Tech_Adoption         0.0
# Founded_Decade              0.0
# dtype: float64

# %% [markdown]
# ## 42. Reorder the columns so that 'Company_ID' is the first column.

# %%
df = df[['Company_ID'] + [col for col in df.columns if col != 'Company_ID']]
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade
# 0               154.29            2000
# 1               182.03            2000
# 2               108.61            2000
# 3                56.99            1980
# 4               197.19            2010

# %% [markdown]
# ## 43. Create a column 'High_Revenue_Company' which is True if 'Annual_Revenue' > 500 million, else False.

# %%
df['High_Revenue_Company'] = df['Revenue'] > 5e8
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168  0.110274
# 1      779751           Myers and Sons          2001       1199  0.146628
# 2      161950  Barker, Sims and Walker          2008        158  0.760617
# 3      426522             Castro-Simon          1985       2826  0.795535
# 4      688832  Hughes, Mills and Stout          2011       3238  0.705882
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade  High_Revenue_Company
# 0               154.29            2000                 False
# 1               182.03            2000                 False
# 2               108.61            2000                 False
# 3                56.99            1980                 False
# 4               197.19            2010                 False

# %% [markdown]
# ## 44. Split the dataset into training (80%) and testing (20%) sets based on 'Company_ID'.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2, random_state=42)
train.shape, test.shape
# Out:
# ((800, 18), (200, 18))

# %% [markdown]
# ## 45. Create a pipeline to preprocess the 'Annual_Revenue' and 'Market_Share' columns.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([
    ('scaler', StandardScaler())
])
df[['Revenue', 'Market_Share']] = pipeline.fit_transform(df[['Revenue', 'Market_Share']])
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168 -1.356153
# 1      779751           Myers and Sons          2001       1199 -1.229210
# 2      161950  Barker, Sims and Walker          2008        158  0.914712
# 3      426522             Castro-Simon          1985       2826  1.036641
# 4      688832  Hughes, Mills and Stout          2011       3238  0.723592
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade  High_Revenue_Company
# 0               154.29            2000                 False
# 1               182.03            2000                 False
# 2               108.61            2000                 False
# 3                56.99            1980                 False
# 4               197.19            2010                 False

# %% [markdown]
# ## 46. Export the cleaned dataset to a new CSV file.

# %%
df.to_csv('cleaned_software_companies_dataset.csv', index=False)

# %% [markdown]
# ## 47. Save the dataset in Excel format with multiple sheets based on 'Product_Lines'.

# %%
with pd.ExcelWriter('software_companies_by_product_line.xlsx') as writer:
    for product_line in df['Product_Lines'].unique():
        df[df['Product_Lines'] == product_line].to_excel(writer, sheet_name=product_line, index=False)

# %% [markdown]
# ## 48. Create a summary report of the dataset including key statistics and visualizations.

# %%
df.describe(include='all')
# Out:
#            Company_ID   Company_Name  Year_Founded   Employees       Revenue  \
# count     1000.000000           1000   1000.000000  1000.00000  1.000000e+03
# unique            NaN            982           NaN         NaN           NaN
# top               NaN  Johnson Group           NaN         NaN           NaN
# freq              NaN              3           NaN         NaN           NaN
# mean    545713.387000            NaN   1999.313000  2451.20000  9.414691e-17
# std     258624.607673            NaN     11.466844  1386.23205  1.000500e+00
# min     100317.000000            NaN   1980.000000    53.00000 -1.741206e+00
# 25%     323647.750000            NaN   1989.000000  1322.25000 -8.311083e-01
# 50%     547569.000000            NaN   1999.000000  2393.50000 -2.289951e-02
# 75%     765875.250000            NaN   2009.000000  3582.25000  8.512783e-01
# max     999534.000000            NaN   2019.000000  4998.00000  1.750591e+00
#
#         Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# count   1.000000e+03          1000  1.000000e+03       1000.000000
# unique           NaN             5           NaN               NaN
# top              NaN      Hardware           NaN               NaN
# freq             NaN           209           NaN               NaN
# mean   -1.421085e-17           NaN  2.475394e+07         50.558820
# std     1.000500e+00           NaN  1.381845e+07         27.771751
# min    -1.722192e+00           NaN  5.356223e+05          0.000000
# 25%    -8.721861e-01           NaN  1.364892e+07         27.315000
# 50%    -1.023964e-02           NaN  2.496674e+07         51.160000
# 75%     8.581889e-01           NaN  3.653031e+07         74.165000
# max     1.687384e+00           NaN  4.930247e+07         99.910000
#
#         Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# count           1000.000000               1000.000000  1000.000000
# unique                  NaN                       NaN          NaN
# top                     NaN                       NaN          NaN
# freq                    NaN                       NaN          NaN
# mean              51.553950                 49.559770    24.687000
# std               28.259477                 29.469011    11.466844
# min                0.030000                  0.040000     5.000000
# 25%               27.860000                 22.735000    15.000000
# 50%               52.025000                 50.210000    25.000000
# 75%               75.920000                 75.122500    35.000000
# max               99.970000                 99.980000    44.000000
#
#         Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# count            1000.000000           1.000000e+03                  1000
# unique                   NaN                    NaN                     1
# top                      NaN                    NaN                   Low
# freq                     NaN                    NaN                  1000
# mean                0.000450           9.414691e-17                   NaN
# std                 0.000932           1.000500e+00                   NaN
# min                 0.000000          -1.741206e+00                   NaN
# 25%                 0.000108          -8.311083e-01                   NaN
# 50%                 0.000203          -2.289951e-02                   NaN
# 75%                 0.000396           8.512783e-01                   NaN
# max                 0.015564           1.750591e+00                   NaN
#
#         Total_Tech_Adoption  Founded_Decade High_Revenue_Company
# count           1000.000000     1000.000000                 1000
# unique                  NaN             NaN                    1
# top                     NaN             NaN                False
# freq                    NaN             NaN                 1000
# mean             151.672540     1994.810000                  NaN
# std               50.714441       11.211137                  NaN
# min               18.760000     1980.000000                  NaN
# 25%              116.405000     1980.000000                  NaN
# 50%              150.870000     1990.000000                  NaN
# 75%              184.855000     2000.000000                  NaN
# max              289.260000     2010.000000                  NaN

# %%
def clean_data(df):
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    # Fill missing values with the mean for numerical columns only
    df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)
    return df

cleaned_df = clean_data(df.copy())
cleaned_df.head()

# %% [markdown]
# ## 49. Write a function to automate the data cleaning process for this dataset.

# %%
def clean_data(df):
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    # Fill missing values with the mean for numerical columns only
    df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)
    return df

cleaned_df = clean_data(df.copy())
cleaned_df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168 -1.356153
# 1      779751           Myers and Sons          2001       1199 -1.229210
# 2      161950  Barker, Sims and Walker          2008        158  0.914712
# 3      426522             Castro-Simon          1985       2826  1.036641
# 4      688832  Hughes, Mills and Stout          2011       3238  0.723592
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade  High_Revenue_Company  Innovation_Index
# 0               154.29            2000                 False      2.603616e+09
# 1               182.03            2000                 False      5.989831e+09
# 2               108.61            2000                 False      4.929474e+09
# 3                56.99            1980                 False      2.149186e+09
# 4               197.19            2010                 False      1.995073e+09

# %% [markdown]
# ## 50. Create a new column 'Innovation_Index' using a simple formula on 'R&D_Spending' and 'Total_Tech_Adoption'.

# %%
df['Innovation_Index'] = df['R&D_Spending'] * df['Total_Tech_Adoption']
df.head()
# Out:
#    Company_ID             Company_Name  Year_Founded  Employees   Revenue  \
# 0      115525                 Mora-Kim          2002       2168 -1.356153
# 1      779751           Myers and Sons          2001       1199 -1.229210
# 2      161950  Barker, Sims and Walker          2008        158  0.914712
# 3      426522             Castro-Simon          1985       2826  1.036641
# 4      688832  Hughes, Mills and Stout          2011       3238  0.723592
#
#    Market_Share Product_Lines  R&D_Spending  Adoption_Rate_AI  \
# 0     -0.962082      Hardware   16874822.81             51.54
# 1      1.547507      Hardware   32905733.95             57.78
# 2      1.462899   IT Services   45386922.83             73.96
# 3      1.487463      Services   37711635.48             13.65
# 4     -0.148752      Software   10117516.57             84.11
#
#    Adoption_Rate_Cloud  Adoption_Rate_Blockchain  Company_Age  \
# 0                63.10                     39.65           22
# 1                28.83                     95.42           23
# 2                22.23                     12.42           16
# 3                21.07                     22.27           39
# 4                71.37                     41.71           13
#
#    Revenue_per_Employee  Annual_Revenue_Zscore Market_Share_Category  \
# 0              0.000051              -1.356153                   Low
# 1              0.000122              -1.229210                   Low
# 2              0.004814               0.914712                   Low
# 3              0.000282               1.036641                   Low
# 4              0.000218               0.723592                   Low
#
#    Total_Tech_Adoption  Founded_Decade  High_Revenue_Company  Innovation_Index
# 0               154.29            2000                 False      2.603616e+09
# 1               182.03            2000                 False      5.989831e+09
# 2               108.61            2000                 False      4.929474e+09
# 3                56.99            1980                 False      2.149186e+09
# 4               197.19            2010                 False      1.995073e+09
