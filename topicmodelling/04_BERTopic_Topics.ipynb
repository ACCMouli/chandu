# %% [markdown]
# <a href="https://colab.research.google.com/github/ACCMouli/chandu/blob/main/topicmodelling/04_BERTopic_Topics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERTopic Topic Modeling

# %% [markdown]
# ## Step 0: Install & Imports

# %%
# !pip3 install bertopic sentence-transformers pandas hdbscan==0.8.29
import pandas as pd
from bertopic import BERTopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 4.4 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.12/dist-packages/hdbscan/plots.py:448: SyntaxWarning: invalid escape sequence '\l'
#   axis.set_ylabel('$\lambda$ value')
# /usr/local/lib/python3.12/dist-packages/hdbscan/robust_single_linkage_.py:175: SyntaxWarning: invalid escape sequence '\{'
#   $max \{ core_k(a), core_k(b), 1/\alpha d(a,b) \}$.

# %% [markdown]
# ## Step 1: Load the CSV

# %%
csv_path = "https://github.com/giridhar276/genai/raw/refs/heads/main/topicmodelling/topics_100.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#    id                                               text
# 0  79        IPv6 users cannot reach the upload endpoint
# 1   4  Login form shows captcha error even for first ...
# 2  55   Audit logs missing entries for sensitive actions
# 3   3  SSO login loops back to the sign-in page repea...
# 4  72       Corporate proxy strips authorization headers

# %% [markdown]
# ## Step 2: Fit BERTopic

# %%
docs = df["text"].astype(str).tolist()
topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(docs)
len(set([t for t in topics if t != -1]))
# Out:
# 2025-09-16 10:24:20,552 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-09-16 10:24:25,245 - BERTopic - Embedding - Completed ✓
# 2025-09-16 10:24:25,248 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-09-16 10:24:34,846 - BERTopic - Dimensionality - Completed ✓
# ...

# %% [markdown]
# ## Step 3: Inspect Topics

# %%
info = topic_model.get_topic_info()
info.head(15)
# Out:
#    Topic  Count                         Name  \
# 0     -1     43       -1_not_without_when_on
# 1      0     34        0_login_not_after_for
# 2      1     12       1_the_on_to_pagination
# 3      2     11  2_slowly_large_when_caching
#
#                                       Representation  \
# 0  [not, without, when, on, api, do, notification...
# 1  [login, not, after, for, does, on, password, f...
# 2  [the, on, to, pagination, links, report, butto...
# 3  [slowly, large, when, caching, assets, batch, ...
#
#                                  Representative_Docs
# 0  [Public API docs do not match current response...
# 1  [User session does not expire after password c...
# 2  [Modal dialog scrolls behind the page on mobil...
# 3  [Latency spikes when exporting large CSV repor...

# %% [markdown]
# ## Step 4: Top Words of a Topic

# %%
first_topic = info.iloc[1]["Topic"] if info.iloc[0]["Topic"] == -1 else info.iloc[0]["Topic"]
topic_model.get_topic(first_topic)
# Out:
# [('login', np.float64(0.13390484410928852)),
#  ('not', np.float64(0.10613367612604865)),
#  ('after', np.float64(0.09771336343183953)),
#  ('for', np.float64(0.05925729681583864)),
#  ('does', np.float64(0.05815319105120783)),
#  ('on', np.float64(0.050411508796854146)),
#  ('password', np.float64(0.0496620290130083)),
#  ('fails', np.float64(0.041474955917543584)),
#  ('ip', np.float64(0.03633346653795065)),
#  ('invoice', np.float64(0.03633346653795065))]

# %% [markdown]
# ## Step 5: Save

# %%
df["topic"] = topics
df.to_csv("bertopic_topics_assigned.csv", index=False)
df.head()
# Out:
#    id                                               text  topic
# 0  79        IPv6 users cannot reach the upload endpoint     -1
# 1   4  Login form shows captcha error even for first ...      0
# 2  55   Audit logs missing entries for sensitive actions     -1
# 3   3  SSO login loops back to the sign-in page repea...      0
# 4  72       Corporate proxy strips authorization headers      0

# %% [markdown]
# ## Step 6: Optional Visualizations

# %%
# topic_model.visualize_topics()
# topic_model.visualize_hierarchy()
# topic_model.visualize_barchart()
# topic_model.visualize_documents(docs)
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/spectral.py:519: RuntimeWarning: k >= N for N * N square matrix. Attempting to use scipy.linalg.eigh instead.
#   eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1769900972.py in <cell line: 0>()
# ----> 1 topic_model.visualize_topics()
#       2 topic_model.visualize_hierarchy()
#       3 topic_model.visualize_barchart()
#       4 topic_model.visualize_documents(docs)
#
# /usr/local/lib/python3.12/dist-packages/bertopic/_bertopic.py in visualize_topics(self, topics, top_n_topics, use_ctfidf, custom_labels, title, width, height)
#    2440         """
#    2441         check_is_fitted(self)
# -> 2442         return plotting.visualize_topics(
#    2443             self,
#    2444             topics=topics,
#
# ...
